# %% [markdown]
# ## Setting up basic Graph

# %%
from langgraph.graph import StateGraph, START, END
from dotenv import load_dotenv
from typing import TypedDict
from langchain_core.tools import tool
import gradio as gr

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import importlib
import os
from typing import Any, Optional

from langchain_core.tools import tool

import leadfinder.providers.base as provider_base
import leadfinder.providers.google_places as provider_google

importlib.reload(provider_base)
importlib.reload(provider_google)

from leadfinder.providers.base import Anchor, RawCandidate
from leadfinder.providers.google_places import GooglePlacesConfig, GooglePlacesProvider


async def google_places_search_async(
    query: str,
    *,
    center_lat: Optional[float] = None,
    center_lng: Optional[float] = None,
    radius_km: Optional[float] = None,
    max_results: int = 5,
) -> list[RawCandidate]:
    api_key = os.getenv("GOOGLE_PLACES_API_KEY")
    if not api_key:
        return [
            RawCandidate(
                source="google_places",
                source_id="",
                payload={"error": "GOOGLE_PLACES_API_KEY is not set"},
                name="",
                address_full="",
                city=None,
                region=None,
                country=None,
                lat=None,
                lng=None,
                phone=None,
                website_url=None,
                categories=[],
            )
        ]

    cfg = GooglePlacesConfig(api_key=api_key)
    if center_lat is None or center_lng is None or radius_km is None:
        anchor = None
    else:
        anchor = Anchor(
            center_lat=center_lat,
            center_lng=center_lng,
            radius_km=radius_km,
            quota=max_results,
        )

    async with GooglePlacesProvider(cfg) as provider:
        candidates, _ = await provider.search(query, anchor)

    return candidates[: max(1, max_results)]


@tool
def google_maps_search(
    query: str,
    center_lat: Optional[float] = None,
    center_lng: Optional[float] = None,
    radius_km: Optional[float] = None,
    max_results: int = 5,
) -> list[dict[str, Any]]:
    """Search Google Places using the provider implementation."""
    import asyncio

    results = asyncio.run(
        google_places_search_async(
            query,
            center_lat=center_lat,
            center_lng=center_lng,
            radius_km=radius_km,
            max_results=max_results,
        )
    )

    businesses = []
    for item in results:
        businesses.append(
            {
                "name": item.name,
                "address": item.address_full,
                "place_id": item.source_id,
                "types": item.categories,
                "phone": item.phone,
                "website": item.website_url,
                "lat": item.lat,
                "lng": item.lng,
            }
        )

    return businesses

# %%
import json

sample_results = await google_places_search_async(
    "pharmacies in Vancouver, Canada",
    max_results=10,
)

print(json.dumps([r.__dict__ for r in sample_results], indent=2))
# Out:
# [
#   {
#     "source": "google_places",
#     "source_id": "ChIJUVFDWytyhlQRB5nvG1vemCo",
#     "payload": {
#       "search_place": {
#         "id": "ChIJUVFDWytyhlQRB5nvG1vemCo",
#         "types": [
#           "pharmacy",
#           "gift_shop",
#           "drugstore",
#           "health",
#           "store",
#           "point_of_interest",
#           "establishment"
#         ],
#         "formattedAddress": "1125 Davie St, Vancouver, BC V6E 1N2",
#         "location": {
#           "latitude": 49.28098,
#           "longitude": -123.13150200000001
#         },
#         "displayName": {
#           "text": "Shoppers Drug Mart"
#         }
#       },
#       "details": {
#         "id": "ChIJUVFDWytyhlQRB5nvG1vemCo",
#         "types": [
#           "pharmacy",
#           "drugstore",
#           "gift_shop",
#           "store",
#           "health",
#           "point_of_interest",
#           "establishment"
#         ],
#         "nationalPhoneNumber": "(604) 669-2424",
#         "formattedAddress": "1125 Davie St, Vancouver, BC V6E 1N2, Canada",
#         "location": {
#           "latitude": 49.28098,
#           "longitude": -123.13150200000001
#         },
#         "websiteUri": "https://www.shoppersdrugmart.ca/en/store-locator/store/272/?utm_source=G&utm_medium=lpm&utm_campaign=LPM_SDM",
#         "displayName": {
#           "text": "Shoppers Drug Mart"
#         }
#       }
#     },
#     "name": "Shoppers Drug Mart",
#     "address_full": "1125 Davie St, Vancouver, BC V6E 1N2, Canada",
#     "city": "Vancouver",
#     "region": "BC V6E 1N2",
#     "country": "Canada",
#     "lat": 49.28098,
#     "lng": -123.13150200000001,
#     "phone": "(604) 669-2424",
#     "website_url": "https://www.shoppersdrugmart.ca/en/store-locator/store/272/?utm_source=G&utm_medium=lpm&utm_campaign=LPM_SDM",
#     "categories": [
#       "pharmacy",
#       "drugstore",
#       "gift_shop",
#       "store",
#       "health",
#       "point_of_interest",
#       "establishment"
#     ]
#   },
#   {
#     "source": "google_places",
#     "source_id": "ChIJNf_mEX9xhlQRTc1iaAxk12M",
#     "payload": {
#       "search_place": {
#         "id": "ChIJNf_mEX9xhlQRTc1iaAxk12M",
#         "types": [
#           "pharmacy",
#           "electronics_store",
#           "grocery_store",
#           "food_store",
#           "home_goods_store",
#           "health",
#           "food",
#           "store",
#           "point_of_interest",
#           "establishment"
#         ],
#         "formattedAddress": "710 Granville St, Vancouver, BC V6Z 1E4",
#         "location": {
#           "latitude": 49.282154299999995,
#           "longitude": -123.1181723
#         },
#         "displayName": {
#           "text": "London Drugs"
#         }
#       },
#       "details": {
#         "id": "ChIJNf_mEX9xhlQRTc1iaAxk12M",
#         "types": [
#           "pharmacy",
#           "electronics_store",
#           "grocery_store",
#           "home_goods_store",
#           "food_store",
#           "store",
#           "food",
#           "point_of_interest",
#           "health",
#           "establishment"
#         ],
#         "nationalPhoneNumber": "(604) 448-4802",
#         "formattedAddress": "710 Granville St, Vancouver, BC V6Z 1E4, Canada",
#         "location": {
#           "latitude": 49.282154299999995,
#           "longitude": -123.1181723
#         },
#         "websiteUri": "https://www.londondrugs.com/stores/granville-georgia/s/002?utm_source=GMB&utm_medium=Yext",
#         "displayName": {
#           "text": "London Drugs"
#         }
#       }
#     },
#     "name": "London Drugs",
#     "address_full": "710 Granville St, Vancouver, BC V6Z 1E4, Canada",
#     "city": "Vancouver",
#     "region": "BC V6Z 1E4",
#     "country": "Canada",
#     "lat": 49.282154299999995,
#     "lng": -123.1181723,
#     "phone": "(604) 448-4802",
#     "website_url": "https://www.londondrugs.com/stores/granville-georgia/s/002?utm_source=GMB&utm_medium=Yext",
#     "categories": [
#       "pharmacy",
#       "electronics_store",
#       "grocery_store",
#       "home_goods_store",
#       "food_store",
#       "store",
#       "food",
#       "point_of_interest",
#       "health",
#       "establishment"
#     ]
#   },
#   {
#     "source": "google_places",
#     "source_id": "ChIJ-68F_tNzhlQRLIs4gyEnu9c",
#     "payload": {
#       "search_place": {
#         "id": "ChIJ-68F_tNzhlQRLIs4gyEnu9c",
#         "types": [
#           "pharmacy",
#           "gift_shop",
#           "drugstore",
#           "health",
#           "store",
#           "point_of_interest",
#           "establishment"
#         ],
#         "formattedAddress": "1295 Seymour St, Vancouver, BC V6B 3N6",
#         "location": {
#           "latitude": 49.275711,
#           "longitude": -123.12690099999999
#         },
#         "displayName": {
#           "text": "Shoppers Drug Mart"
#         }
#       },
#       "details": {
#         "id": "ChIJ-68F_tNzhlQRLIs4gyEnu9c",
#         "types": [
#           "pharmacy",
#           "drugstore",
#           "gift_shop",
#           "store",
#           "point_of_interest",
#           "health",
#           "establishment"
#         ],
#         "nationalPhoneNumber": "(604) 801-5708",
#         "formattedAddress": "1295 Seymour St, Vancouver, BC V6B 3N6, Canada",
#         "location": {
#           "latitude": 49.275711,
#           "longitude": -123.12690099999999
#         },
#         "websiteUri": "https://www.shoppersdrugmart.ca/en/store-locator/store/2292/?utm_source=G&utm_medium=lpm&utm_campaign=LPM_SDM",
#         "displayName": {
#           "text": "Shoppers Drug Mart"
#         }
#       }
#     },
#     "name": "Shoppers Drug Mart",
#     "address_full": "1295 Seymour St, Vancouver, BC V6B 3N6, Canada",
#     "city": "Vancouver",
#     "region": "BC V6B 3N6",
#     "country": "Canada",
#     "lat": 49.275711,
#     "lng": -123.12690099999999,
#     "phone": "(604) 801-5708",
#     "website_url": "https://www.shoppersdrugmart.ca/en/store-locator/store/2292/?utm_source=G&utm_medium=lpm&utm_campaign=LPM_SDM",
#     "categories": [
#       "pharmacy",
#       "drugstore",
#       "gift_shop",
#       "store",
#       "point_of_interest",
#       "health",
#       "establishment"
#     ]
#   },
#   {
#     "source": "google_places",
#     "source_id": "ChIJP8QqMUlxhlQR-9xDBk3TmMU",
#     "payload": {
#       "search_place": {
#         "id": "ChIJP8QqMUlxhlQR-9xDBk3TmMU",
#         "types": [
#           "pharmacy",
#           "gift_shop",
#           "drugstore",
#           "health",
#           "store",
#           "point_of_interest",
#           "establishment"
#         ],
#         "formattedAddress": "1755 E Broadway, Vancouver, BC V5N 1W2",
#         "location": {
#           "latitude": 49.262552,
#           "longitude": -123.068783
#         },
#         "displayName": {
#           "text": "Shoppers Drug Mart"
#         }
#       },
#       "details": {
#         "id": "ChIJP8QqMUlxhlQR-9xDBk3TmMU",
#         "types": [
#           "pharmacy",
#           "drugstore",
#           "gift_shop",
#           "store",
#           "health",
#           "point_of_interest",
#           "establishment"
#         ],
#         "nationalPhoneNumber": "(604) 872-8451",
#         "formattedAddress": "1755 E Broadway, Vancouver, BC V5N 1W2, Canada",
#         "location": {
#           "latitude": 49.262552,
#           "longitude": -123.068783
#         },
#         "websiteUri": "https://www.shoppersdrugmart.ca/en/store-locator/store/280/?utm_source=G&utm_medium=lpm&utm_campaign=LPM_SDM",
#         "displayName": {
#           "text": "Shoppers Drug Mart"
#         }
#       }
#     },
#     "name": "Shoppers Drug Mart",
#     "address_full": "1755 E Broadway, Vancouver, BC V5N 1W2, Canada",
#     "city": "Vancouver",
#     "region": "BC V5N 1W2",
#     "country": "Canada",
#     "lat": 49.262552,
#     "lng": -123.068783,
#     "phone": "(604) 872-8451",
#     "website_url": "https://www.shoppersdrugmart.ca/en/store-locator/store/280/?utm_source=G&utm_medium=lpm&utm_campaign=LPM_SDM",
#     "categories": [
#       "pharmacy",
#       "drugstore",
#       "gift_shop",
#       "store",
#       "health",
#       "point_of_interest",
#       "establishment"
#     ]
#   },
#   {
#     "source": "google_places",
#     "source_id": "ChIJWwdnroZxhlQR848QlQLLgmQ",
#     "payload": {
#       "search_place": {
#         "id": "ChIJWwdnroZxhlQR848QlQLLgmQ",
#         "types": [
#           "pharmacy",
#           "gift_shop",
#           "drugstore",
#           "health",
#           "store",
#           "point_of_interest",
#           "establishment"
#         ],
#         "formattedAddress": "1202 W Pender St, Vancouver, BC V6E 2S9",
#         "location": {
#           "latitude": 49.288363,
#           "longitude": -123.123836
#         },
#         "displayName": {
#           "text": "Shoppers Drug Mart"
#         }
#       },
#       "details": {
#         "id": "ChIJWwdnroZxhlQR848QlQLLgmQ",
#         "types": [
#           "pharmacy",
#           "drugstore",
#           "gift_shop",
#           "store",
#           "point_of_interest",
#           "health",
#           "establishment"
#         ],
#         "nationalPhoneNumber": "(604) 605-1200",
#         "formattedAddress": "1202 W Pender St, Vancouver, BC V6E 2S9, Canada",
#         "location": {
#           "latitude": 49.288363,
#           "longitude": -123.123836
#         },
#         "websiteUri": "https://www.shoppersdrugmart.ca/en/store-locator/store/2275/?utm_source=G&utm_medium=lpm&utm_campaign=LPM_SDM",
#         "displayName": {
#           "text": "Shoppers Drug Mart"
#         }
#       }
#     },
#     "name": "Shoppers Drug Mart",
#     "address_full": "1202 W Pender St, Vancouver, BC V6E 2S9, Canada",
#     "city": "Vancouver",
#     "region": "BC V6E 2S9",
#     "country": "Canada",
#     "lat": 49.288363,
#     "lng": -123.123836,
#     "phone": "(604) 605-1200",
#     "website_url": "https://www.shoppersdrugmart.ca/en/store-locator/store/2275/?utm_source=G&utm_medium=lpm&utm_campaign=LPM_SDM",
#     "categories": [
#       "pharmacy",
#       "drugstore",
#       "gift_shop",
#       "store",
#       "point_of_interest",
#       "health",
#       "establishment"
#     ]
#   },
#   {
#     "source": "google_places",
#     "source_id": "ChIJ6Y9wwYBxhlQR5ysHTypCc1A",
#     "payload": {
#       "search_place": {
#         "id": "ChIJ6Y9wwYBxhlQR5ysHTypCc1A",
#         "types": [
#           "pharmacy",
#           "electronics_store",
#           "grocery_store",
#           "food_store",
#           "home_goods_store",
#           "health",
#           "food",
#           "store",
#           "point_of_interest",
#           "establishment"
#         ],
#         "formattedAddress": "1187 Robson St, Vancouver, BC V6E 1B5",
#         "location": {
#           "latitude": 49.285913199999996,
#           "longitude": -123.12640169999997
#         },
#         "displayName": {
#           "text": "London Drugs"
#         }
#       },
#       "details": {
#         "id": "ChIJ6Y9wwYBxhlQR5ysHTypCc1A",
#         "types": [
#           "pharmacy",
#           "grocery_store",
#           "electronics_store",
#           "food_store",
#           "home_goods_store",
#           "store",
#           "health",
#           "food",
#           "point_of_interest",
#           "establishment"
#         ],
#         "nationalPhoneNumber": "(604) 448-4819",
#         "formattedAddress": "1187 Robson St, Vancouver, BC V6E 1B5, Canada",
#         "location": {
#           "latitude": 49.285913199999996,
#           "longitude": -123.12640169999997
#         },
#         "websiteUri": "https://www.londondrugs.com/stores/robson-street/s/019?utm_source=GMB&utm_medium=Yext",
#         "displayName": {
#           "text": "London Drugs"
#         }
#       }
#     },
#     "name": "London Drugs",
#     "address_full": "1187 Robson St, Vancouver, BC V6E 1B5, Canada",
#     "city": "Vancouver",
#     "region": "BC V6E 1B5",
#     "country": "Canada",
#     "lat": 49.285913199999996,
#     "lng": -123.12640169999997,
#     "phone": "(604) 448-4819",
#     "website_url": "https://www.londondrugs.com/stores/robson-street/s/019?utm_source=GMB&utm_medium=Yext",
#     "categories": [
#       "pharmacy",
#       "grocery_store",
#       "electronics_store",
#       "food_store",
#       "home_goods_store",
#       "store",
#       "health",
#       "food",
#       "point_of_interest",
#       "establishment"
#     ]
#   },
#   {
#     "source": "google_places",
#     "source_id": "ChIJ548RMIBxhlQRIGK6DgsQNgg",
#     "payload": {
#       "search_place": {
#         "id": "ChIJ548RMIBxhlQRIGK6DgsQNgg",
#         "types": [
#           "pharmacy",
#           "gift_shop",
#           "drugstore",
#           "health",
#           "store",
#           "point_of_interest",
#           "establishment"
#         ],
#         "formattedAddress": "748 Burrard St Unit 104 & 201, Vancouver, BC V6Z 1X5",
#         "location": {
#           "latitude": 49.283547999999996,
#           "longitude": -123.122085
#         },
#         "displayName": {
#           "text": "Shoppers Drug Mart"
#         }
#       },
#       "details": {
#         "id": "ChIJ548RMIBxhlQRIGK6DgsQNgg",
#         "types": [
#           "pharmacy",
#           "drugstore",
#           "gift_shop",
#           "health",
#           "store",
#           "point_of_interest",
#           "establishment"
#         ],
#         "nationalPhoneNumber": "(778) 330-4711",
#         "formattedAddress": "748 Burrard St Unit 104 & 201, Vancouver, BC V6Z 1X5, Canada",
#         "location": {
#           "latitude": 49.283547999999996,
#           "longitude": -123.122085
#         },
#         "websiteUri": "https://www.shoppersdrugmart.ca/en/store-locator/store/2245/?utm_source=G&utm_medium=lpm&utm_campaign=LPM_SDM",
#         "displayName": {
#           "text": "Shoppers Drug Mart"
#         }
#       }
#     },
#     "name": "Shoppers Drug Mart",
#     "address_full": "748 Burrard St Unit 104 & 201, Vancouver, BC V6Z 1X5, Canada",
#     "city": "Vancouver",
#     "region": "BC V6Z 1X5",
#     "country": "Canada",
#     "lat": 49.283547999999996,
#     "lng": -123.122085,
#     "phone": "(778) 330-4711",
#     "website_url": "https://www.shoppersdrugmart.ca/en/store-locator/store/2245/?utm_source=G&utm_medium=lpm&utm_campaign=LPM_SDM",
#     "categories": [
#       "pharmacy",
#       "drugstore",
#       "gift_shop",
#       "health",
#       "store",
#       "point_of_interest",
#       "establishment"
#     ]
#   },
#   {
#     "source": "google_places",
#     "source_id": "ChIJIzeRzehzhlQRPKE0jAK-37E",
#     "payload": {
#       "search_place": {
#         "id": "ChIJIzeRzehzhlQRPKE0jAK-37E",
#         "types": [
#           "pharmacy",
#           "gift_shop",
#           "drugstore",
#           "health",
#           "store",
#           "point_of_interest",
#           "establishment"
#         ],
#         "formattedAddress": "3277 Cambie St., Vancouver, BC V5Z 2W3",
#         "location": {
#           "latitude": 49.2567661,
#           "longitude": -123.11536389999999
#         },
#         "displayName": {
#           "text": "Shoppers Drug Mart"
#         }
#       },
#       "details": {
#         "id": "ChIJIzeRzehzhlQRPKE0jAK-37E",
#         "types": [
#           "pharmacy",
#           "drugstore",
#           "gift_shop",
#           "store",
#           "health",
#           "point_of_interest",
#           "establishment"
#         ],
#         "nationalPhoneNumber": "(604) 708-9090",
#         "formattedAddress": "3277 Cambie St., Vancouver, BC V5Z 2W3, Canada",
#         "location": {
#           "latitude": 49.2567661,
#           "longitude": -123.11536389999999
#         },
#         "websiteUri": "https://www.shoppersdrugmart.ca/en/store-locator/store/2234/?utm_source=G&utm_medium=lpm&utm_campaign=LPM_SDM",
#         "displayName": {
#           "text": "Shoppers Drug Mart"
#         }
#       }
#     },
#     "name": "Shoppers Drug Mart",
#     "address_full": "3277 Cambie St., Vancouver, BC V5Z 2W3, Canada",
#     "city": "Vancouver",
#     "region": "BC V5Z 2W3",
#     "country": "Canada",
#     "lat": 49.2567661,
#     "lng": -123.11536389999999,
#     "phone": "(604) 708-9090",
#     "website_url": "https://www.shoppersdrugmart.ca/en/store-locator/store/2234/?utm_source=G&utm_medium=lpm&utm_campaign=LPM_SDM",
#     "categories": [
#       "pharmacy",
#       "drugstore",
#       "gift_shop",
#       "store",
#       "health",
#       "point_of_interest",
#       "establishment"
#     ]
#   },
#   {
#     "source": "google_places",
#     "source_id": "ChIJf5rQs3hxhlQR9yl9vuAYbiw",
#     "payload": {
#       "search_place": {
#         "id": "ChIJf5rQs3hxhlQR9yl9vuAYbiw",
#         "types": [
#           "pharmacy",
#           "gift_shop",
#           "drugstore",
#           "health",
#           "store",
#           "point_of_interest",
#           "establishment"
#         ],
#         "formattedAddress": "586 Granville St, Vancouver, BC V6C 1X5",
#         "location": {
#           "latitude": 49.283594,
#           "longitude": -123.11596199999998
#         },
#         "displayName": {
#           "text": "Shoppers Drug Mart"
#         }
#       },
#       "details": {
#         "id": "ChIJf5rQs3hxhlQR9yl9vuAYbiw",
#         "types": [
#           "pharmacy",
#           "drugstore",
#           "gift_shop",
#           "store",
#           "health",
#           "point_of_interest",
#           "establishment"
#         ],
#         "nationalPhoneNumber": "(604) 683-4063",
#         "formattedAddress": "586 Granville St, Vancouver, BC V6C 1X5, Canada",
#         "location": {
#           "latitude": 49.283594,
#           "longitude": -123.11596199999998
#         },
#         "websiteUri": "https://www.shoppersdrugmart.ca/en/store-locator/store/2277/?utm_source=G&utm_medium=lpm&utm_campaign=LPM_SDM",
#         "displayName": {
#           "text": "Shoppers Drug Mart"
#         }
#       }
#     },
#     "name": "Shoppers Drug Mart",
#     "address_full": "586 Granville St, Vancouver, BC V6C 1X5, Canada",
#     "city": "Vancouver",
#     "region": "BC V6C 1X5",
#     "country": "Canada",
#     "lat": 49.283594,
#     "lng": -123.11596199999998,
#     "phone": "(604) 683-4063",
#     "website_url": "https://www.shoppersdrugmart.ca/en/store-locator/store/2277/?utm_source=G&utm_medium=lpm&utm_campaign=LPM_SDM",
#     "categories": [
#       "pharmacy",
#       "drugstore",
#       "gift_shop",
#       "store",
#       "health",
#       "point_of_interest",
#       "establishment"
#     ]
#   },
#   {
#     "source": "google_places",
#     "source_id": "ChIJT64wLLhzhlQR2FMLAyx0h6g",
#     "payload": {
#       "search_place": {
#         "id": "ChIJT64wLLhzhlQR2FMLAyx0h6g",
#         "types": [
#           "pharmacy",
#           "gift_shop",
#           "drugstore",
#           "health",
#           "store",
#           "point_of_interest",
#           "establishment"
#         ],
#         "formattedAddress": "1780 W Broadway, Vancouver, BC V6J 1Y1",
#         "location": {
#           "latitude": 49.263501999999995,
#           "longitude": -123.14483000000001
#         },
#         "displayName": {
#           "text": "Shoppers Drug Mart"
#         }
#       },
#       "details": {
#         "id": "ChIJT64wLLhzhlQR2FMLAyx0h6g",
#         "types": [
#           "pharmacy",
#           "drugstore",
#           "gift_shop",
#           "store",
#           "health",
#           "point_of_interest",
#           "establishment"
#         ],
#         "nationalPhoneNumber": "(604) 736-6006",
#         "formattedAddress": "1780 W Broadway, Vancouver, BC V6J 1Y1, Canada",
#         "location": {
#           "latitude": 49.263501999999995,
#           "longitude": -123.14483000000001
#         },
#         "websiteUri": "https://www.shoppersdrugmart.ca/en/store-locator/store/2221/?utm_source=G&utm_medium=lpm&utm_campaign=LPM_SDM",
#         "displayName": {
#           "text": "Shoppers Drug Mart"
#         }
#       }
#     },
#     "name": "Shoppers Drug Mart",
#     "address_full": "1780 W Broadway, Vancouver, BC V6J 1Y1, Canada",
#     "city": "Vancouver",
#     "region": "BC V6J 1Y1",
#     "country": "Canada",
#     "lat": 49.263501999999995,
#     "lng": -123.14483000000001,
#     "phone": "(604) 736-6006",
#     "website_url": "https://www.shoppersdrugmart.ca/en/store-locator/store/2221/?utm_source=G&utm_medium=lpm&utm_campaign=LPM_SDM",
#     "categories": [
#       "pharmacy",
#       "drugstore",
#       "gift_shop",
#       "store",
#       "health",
#       "point_of_interest",
#       "establishment"
#     ]
#   }
# ]

# %%
import json


class ChatState(TypedDict):
    messages: list[dict]


def agent(state: ChatState) -> ChatState:
    messages = state["messages"]
    user_msg = next((m for m in reversed(messages) if m["role"] == "user"), None)
    query = user_msg["content"] if user_msg else ""

    tool_output = google_maps_search.invoke({"query": query, "max_results": 5})
    assistant_text = json.dumps(tool_output, indent=2)

    messages = messages + [{"role": "assistant", "content": assistant_text}]
    return {"messages": messages}


graph_builder = StateGraph(ChatState)
graph_builder.add_node("agent", agent)
graph_builder.add_edge(START, "agent")
graph_builder.add_edge("agent", END)
graph = graph_builder.compile()

# %%
import json


def respond(message: str, history: list[dict]) -> tuple[list[dict], str]:
    messages: list[dict] = list(history)
    messages.append({"role": "user", "content": message})

    state = graph.invoke({"messages": messages})
    assistant_text = state["messages"][-1]["content"]
    messages.append({"role": "assistant", "content": assistant_text})

    debug_text = json.dumps(messages, indent=2)
    print(debug_text)
    return messages, debug_text


with gr.Blocks() as demo:
    gr.Markdown("# LeadFinder Mock Chat")
    chatbot = gr.Chatbot(height=320)
    msg = gr.Textbox(placeholder="Ask for leads, e.g. 'Plumbers in Chicago'")
    clear = gr.Button("Clear")
    debug = gr.Textbox(label="Debug messages", lines=10, interactive=False)

    msg.submit(respond, [msg, chatbot], [chatbot, debug])
    clear.click(lambda: ([], ""), None, [chatbot, debug])


demo.launch(inline=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "/Users/zoranjeremic/Sources/SourceLearningAI/leadfinder_service/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/zoranjeremic/Sources/SourceLearningAI/leadfinder_service/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/zoranjeremic/Sources/SourceLearningAI/leadfinder_service/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2163, in process_api
#     data = await self.postprocess_data(block_fn, result["prediction"], state)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/zoranjeremic/Sources/SourceLearningAI/leadfinder_service/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1940, in postprocess_data
#     prediction_value = block.postprocess(prediction_value)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/zoranjeremic/Sources/SourceLearningAI/leadfinder_service/.venv/lib/python3.12/site-packages/gradio/components/chatbot.py", line 704, in postprocess
#     self._check_format(value)
#   File "/Users/zoranjeremic/Sources/SourceLearningAI/leadfinder_service/.venv/lib/python3.12/site-packages/gradio/components/chatbot.py", line 402, in _check_format
#     raise Error(
# gradio.exceptions.Error: "Data incompatible with messages format. Each message should be a dictionary with 'role' and 'content' keys or a ChatMessage object."
